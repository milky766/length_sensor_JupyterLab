# %%
count = input("回数を入力してください: ")
type_val = input("種類を入力してください: ")
pressure_val = input("圧力を入力してください: ")
# Out:
# 回数を入力してください:  2
# 種類を入力してください:  6
# 圧力を入力してください:  3

# %%
import matplotlib.pyplot as plt
import datetime
import time
import serial

com = serial.Serial("COM12", 115200)

path = 'C:\\Users\\Mizuki\\大学\\研究\\length_sensor\\JupyterLab\\data\\pressure_control\\'

file_name = f"{datetime.datetime.now().strftime('%Y%m%d')}_{count}_{type_val}_{pressure_val}_p"
date = datetime.datetime.now().strftime("%Y-%m-%d %H:%M:%S")
sec_finish = 20  # arduino側の作動時間を上回るとプログラムが正常に終了しなくなる
print('start!')

t0 = time.time()

# データを保存するリスト
time_vals = []
p_vals = []

with open(path + file_name + ".csv", "a", encoding='cp1252') as f:
    print("time,p,voltage", file=f) 
    while True:
        t = time.time()
        t_inner = t - t0
        if t_inner > sec_finish:
            print("saved as " + file_name + ".csv" + "!")
            break
        val = str(com.readline().decode('cp1252').rstrip("\r\n"))
        if t_inner > 0.02:
            parts = val.split(',')
            time_val = float(parts[0])
            p_val = float(parts[1]) / 10.0  # bar から MPa への変換

            # データをリストに追加
            time_vals.append(time_val)
            p_vals.append(p_val)

            # ファイルにデータを書き込む
            print("{},{},{}".format(time_val, p_val, parts[2]), file=f)


# グラフの描画
plt.plot(time_vals, p_vals)
plt.xlabel('Time(s)')
plt.ylabel('Pressure(MPa)')

# グラフを保存
save_path = 'C:\\Users\\Mizuki\\University\\Reserch\\length_sensor\\JupyterLab\\graph\\pressure_control\\input\\'
plt.savefig(save_path + file_name + '_input.jpg')

# グラフを表示
plt.show()

com.close()
# Out:
# start!
# saved as 20231123_2_6_3_p.csv!
